# %%
import pandas as pd, numpy as np
import sklearn
import scipy.sparse
import warnings
warnings.filterwarnings('ignore')
from sklearn.feature_extraction.text import CountVectorizer
from scipy import sparse
from sklearn.metrics import confusion_matrix
from bs4 import BeautifulSoup
import re
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfTransformer

# %%
data = pd.read_csv('../data/raw_data/kaggle/train.csv')
labels=(data["toxic"] | data["severe_toxic"] | data["obscene"] | data["threat"] | data["insult"] | data["identity_hate"])
# labels=data["Labels"]
train_data = data[0:100000]
test_data = data[100001:]
train_labels = labels[0:100000]
test_labels = labels[100001:]

corpus = data["comment_text"]

# %%
vectorizer = CountVectorizer(strip_accents='unicode',lowercase=True,stop_words='english', analyzer="word",token_pattern=r'\w{1,}')
X = vectorizer.fit_transform(corpus)
train_feature_vectors_sparse = X[0:100000]
test_feature_vectors_sparse = X[100001:]

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ('tfidf', TfidfTransformer(norm=None, smooth_idf=True, sublinear_tf=False,use_idf=False)),
    ('clf', LogisticRegression(multi_class='ovr'))
])

# %%
from sklearn.metrics import make_scorer

from sklearn.model_selection import GridSearchCV
# tfidf_transformer = TfidfTransformer()
parameters = {'clf__penalty':('l1','l2', None), 'clf__class_weight':(None, 'balanced'), 'clf__solver':('newton-cg', 'lbfgs', 'liblinear')}
grid = GridSearchCV(pipeline, parameters, scoring = make_scorer(f1_score), cv=5, error_score=0.0, verbose=10)

# %%
grid.fit(train_feature_vectors_sparse, train_labels)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg ..
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg ..
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs ......
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.7s remaining:    0.0s
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs ......
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.9s remaining:    0.0s
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs ......
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.2s remaining:    0.0s
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear, score=0.5781249999999999, total=  13.2s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear, score=0.5511309334182861, total=  11.5s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear, score=0.6067346308310164, total=  12.4s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear, score=0.6205425175251448, total=  11.9s
# [CV] clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l1, clf__solver=liblinear, score=0.6558167570825798, total=  12.1s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg, score=0.7552140504939626, total=  15.8s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg, score=0.7436823104693141, total=  14.9s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg, score=0.7561042524005488, total=  14.2s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg, score=0.7459878251245158, total=  16.9s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=newton-cg, score=0.7426655490360436, total=  16.3s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs, score=0.7551799345692475, total=   3.1s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs, score=0.7448161459773294, total=   2.8s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs, score=0.7578082191780822, total=   2.8s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs, score=0.7468214483139857, total=   2.8s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs ......
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=lbfgs, score=0.7413793103448275, total=   2.8s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, score=0.7107583774250441, total=   4.3s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, score=0.7163059163059163, total=   4.8s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, score=0.7339290861919862, total=   4.3s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, score=0.7340759782919167, total=   4.5s
# [CV] clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear ..
# [CV]  clf__class_weight=None, clf__penalty=l2, clf__solver=liblinear, score=0.7014388489208634, total=   4.7s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs ....
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs ....
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs ....
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs ....
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs ....
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=None, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=None, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, score=0.6882474226804124, total=11.6min
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, score=0.6773588835659238, total=13.0min
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, score=0.6755297050270045, total=14.1min
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, score=0.6888001681025424, total=14.4min
# [CV] clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l1, clf__solver=liblinear, score=0.6742738589211619, total=15.3min
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg, score=0.7564979480164158, total=  24.5s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg, score=0.7659474671669793, total=  26.2s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg, score=0.7606481481481482, total=  22.2s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg, score=0.7545412203074057, total=  28.0s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=newton-cg, score=0.7663683466792275, total=  35.4s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, score=0.7545350172215843, total=   3.4s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, score=0.7651888341543513, total=   3.0s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, score=0.7585727525486561, total=   3.5s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, score=0.7548222170578666, total=   3.4s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs ..
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=lbfgs, score=0.7662368112543961, total=   3.3s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, score=0.7467090331366318, total=  13.2s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, score=0.748564867967853, total=  11.2s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, score=0.7558327558327559, total=  14.2s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, score=0.7495946258976142, total=  14.0s
# [CV] clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=l2, clf__solver=liblinear, score=0.7566820276497694, total=  10.3s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=newton-cg, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=lbfgs, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [CV] clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear
# [CV]  clf__class_weight=balanced, clf__penalty=None, clf__solver=liblinear, score=0.0, total=   0.1s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed: 75.0min finished

# %%
grid.best_score_
# Out:
# 0.684472642351882

# %%
a = pd.DataFrame.from_dict(grid.cv_results_)
a
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.740020      0.039021         0.147605        0.023373
# 1        0.511631      0.041203         0.098736        0.023694
# 2        0.680579      0.049231         0.134839        0.015559
# 3        0.494477      0.051836         0.084574        0.011483
# 4        0.748194      0.055394         0.151993        0.012874
# 5        0.472934      0.020001         0.078989        0.005691
# 6        0.763950      0.070123         0.142618        0.023845
# 7        0.511271      0.025680         0.091755        0.016143
# 8        0.750191      0.034636         0.137233        0.008430
# 9        0.501059      0.065832         0.093350        0.019438
# 10       0.708304      0.062266         0.124866        0.008749
# 11       0.437418      0.035327         0.093551        0.017324
#
#    param_tfidf__norm param_tfidf__sublinear_tf param_tfidf__use_idf  \
# 0                 l1                      True                 True
# 1                 l1                      True                False
# 2                 l1                     False                 True
# 3                 l1                     False                False
# 4                 l2                      True                 True
# 5                 l2                      True                False
# 6                 l2                     False                 True
# 7                 l2                     False                False
# 8               None                      True                 True
# 9               None                      True                False
# 10              None                     False                 True
# 11              None                     False                False
#
#                                                params  split0_test_score  \
# 0   {'tfidf__norm': 'l1', 'tfidf__sublinear_tf': T...           0.012860
# 1   {'tfidf__norm': 'l1', 'tfidf__sublinear_tf': T...           0.006144
# 2   {'tfidf__norm': 'l1', 'tfidf__sublinear_tf': F...           0.013468
# 3   {'tfidf__norm': 'l1', 'tfidf__sublinear_tf': F...           0.006144
# 4   {'tfidf__norm': 'l2', 'tfidf__sublinear_tf': T...           0.271907
# 5   {'tfidf__norm': 'l2', 'tfidf__sublinear_tf': T...           0.163888
# 6   {'tfidf__norm': 'l2', 'tfidf__sublinear_tf': F...           0.269824
# 7   {'tfidf__norm': 'l2', 'tfidf__sublinear_tf': F...           0.158730
# 8   {'tfidf__norm': None, 'tfidf__sublinear_tf': T...           0.501990
# 9   {'tfidf__norm': None, 'tfidf__sublinear_tf': T...           0.684741
# 10  {'tfidf__norm': None, 'tfidf__sublinear_tf': F...           0.579112
# 11  {'tfidf__norm': None, 'tfidf__sublinear_tf': F...           0.693781
#
#     split1_test_score       ...         mean_test_score  std_test_score  \
# 0            0.009202       ...                0.014313        0.003363
# 1            0.001847       ...                0.006142        0.002359
# 2            0.012251       ...                0.016496        0.003829
# 3            0.003077       ...                0.007609        0.002807
# 4            0.277939       ...                0.273210        0.003874
# 5            0.161765       ...                0.166618        0.007578
# 6            0.273210       ...                0.269705        0.002433
# 7            0.155549       ...                0.162340        0.005896
# 8            0.503770       ...                0.502590        0.001324
# 9            0.667721       ...                0.675214        0.006701
# 10           0.576490       ...                0.578212        0.002322
# 11           0.676913       ...                0.684473        0.006943
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                10            0.015897            0.016655
# 1                12            0.006910            0.007827
# 2                 9            0.018623            0.019379
# 3                11            0.008592            0.009355
# 4                 5            0.308632            0.305577
# 5                 7            0.178339            0.177700
# 6                 6            0.303034            0.302155
# 7                 8            0.175458            0.174854
# 8                 4            0.691282            0.693052
# 9                 2            0.743491            0.749070
# 10                3            0.772745            0.772254
# 11                1            0.739642            0.745476
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0             0.014835            0.013924            0.015139
# 1             0.006298            0.005838            0.006451
# 2             0.017261            0.016049            0.018018
# 3             0.006910            0.007675            0.008286
# 4             0.305979            0.305458            0.310759
# 5             0.177803            0.174744            0.177048
# 6             0.302025            0.301169            0.305597
# 7             0.173430            0.170704            0.170704
# 8             0.695465            0.692765            0.691343
# 9             0.746746            0.748397            0.746270
# 10            0.774393            0.777857            0.774443
# 11            0.743345            0.745275            0.744052
#
#     mean_train_score  std_train_score
# 0           0.015290         0.000930
# 1           0.006665         0.000675
# 2           0.017866         0.001145
# 3           0.008163         0.000828
# 4           0.307281         0.002090
# 5           0.177127         0.001260
# 6           0.302796         0.001520
# 7           0.173030         0.002010
# 8           0.692781         0.001523
# 9           0.746795         0.001946
# 10          0.774338         0.001964
# 11          0.743558         0.002110
#
# [12 rows x 23 columns]

# %%
grid.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('tfidf', TfidfTransformer(norm=None, smooth_idf=True, sublinear_tf=False,
#          use_idf=False)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
a["params"][9]
# Out:
# {'tfidf__norm': None, 'tfidf__sublinear_tf': True, 'tfidf__use_idf': False}

# %%
a["params"][10]
# Out:
# {'tfidf__norm': None, 'tfidf__sublinear_tf': False, 'tfidf__use_idf': True}
