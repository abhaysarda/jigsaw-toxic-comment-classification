# %%
from time import time
import gensim
import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer
from sklearn import svm
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import train_test_split

# %%
train_data_path = '../data/raw_data/train.csv'
test_data_path = '../data/raw_data/test.csv'
unlabelled_test_path = '../data/raw_data/unlabelled_test.csv'

# %%
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
unlabelled_test = pd.read_csv(unlabelled_test_path)
print(train_data.shape)
print(test_data.shape)
print(unlabelled_test.shape)
# Out:
# (159571, 2)
# (63978, 2)
# (89186, 1)

# %%
comments = list(train_data['Comment'])
comments = comments + (list(test_data['Comment']))
data_label = pd.concat([train_data['Labels'], test_data['Labels']])
comments[0]
# Out:
# "Explanation\r\r\nWhy the edits made under my username Hardcore Metallica Fan were reverted? They weren't vandalisms, just closure on some GAs after I voted at New York Dolls FAC. And please don't remove the template from the talk page since I'm retired now.89.205.38.27"

# %%
train_data, test_data, train_labels, test_labels = train_test_split(preprocessed_comments, data_label , test_size = 0.15, random_state = 39, stratify=data_label)

# %%
test_data[0]
# Out:
# ['appearance',
#  'on',
#  'real',
#  'housewives',
#  'of',
#  'beverly',
#  'hills',
#  'allison',
#  'dubois',
#  'was',
#  'dinner',
#  'guest',
#  'of',
#  'cast',
#  'member',
#  'camille',
#  'grammer',
#  'on',
#  'the',
#  'episode',
#  'of',
#  'the',
#  'real',
#  'housewives',
#  'of',
#  'beverly',
#  'hills',
#  'that',
#  'aired',
#  'december',
#  'entries',
#  'to',
#  'her',
#  'biography',
#  'that',
#  'refer',
#  'to',
#  'her',
#  'guest',
#  'appearance',
#  'have',
#  'been',
#  'deleted',
#  'and',
#  'deemed',
#  'vandalism',
#  'her',
#  'appearance',
#  'was',
#  'notable',
#  'and',
#  'should',
#  'be',
#  'included',
#  'in',
#  'her',
#  'biography',
#  'maybe',
#  'more',
#  'neutrally',
#  'worded',
#  'entry',
#  'can',
#  'be',
#  'added',
#  'that',
#  'includes',
#  'her',
#  'behavior',
#  'and',
#  'some',
#  'of',
#  'the',
#  'things',
#  'she',
#  'said',
#  'on',
#  'the',
#  'show',
#  'direct',
#  'quotes',
#  'from',
#  'dubois',
#  'to',
#  'cast',
#  'member',
#  'kyle',
#  'richards',
#  'include',
#  'your',
#  'husband',
#  'will',
#  'never',
#  'emotionally',
#  'fulfill',
#  'you',
#  'know',
#  'that',
#  'as',
#  'soon',
#  'as',
#  'the',
#  'kids',
#  'are',
#  'bigger',
#  'you',
#  'll',
#  'have',
#  'nothing',
#  'in',
#  'common',
#  'you',
#  'are',
#  'entirely',
#  'washed',
#  'up',
#  'and',
#  'you',
#  'have',
#  'achieved',
#  'nothing',
#  'in',
#  'life',
#  'dubois',
#  'comments',
#  'to',
#  'the',
#  'entire',
#  'dinner',
#  'party',
#  'guests',
#  'concerning',
#  'her',
#  'abilities',
#  'and',
#  'career',
#  'include',
#  'was',
#  'studied',
#  'by',
#  'scientist',
#  'and',
#  'was',
#  'on',
#  'oprah',
#  'like',
#  'drug',
#  'once',
#  'you',
#  'get',
#  'one',
#  'you',
#  'want',
#  'more',
#  'and',
#  'have',
#  'books',
#  'written',
#  'on',
#  'me',
#  'and',
#  'by',
#  'me',
#  'and',
#  'television',
#  'show',
#  'is',
#  'based',
#  'on',
#  'my',
#  'life',
#  'so',
#  'you',
#  'can',
#  'just',
#  'like',
#  'take',
#  'flying',
#  'leap',
#  'after',
#  'the',
#  'party',
#  'was',
#  'over',
#  'dubois',
#  'spoke',
#  'to',
#  'her',
#  'friend',
#  'camille',
#  'grammer',
#  'and',
#  'grammer',
#  'friend',
#  'about',
#  'kyle',
#  'richards',
#  'she',
#  'said',
#  'of',
#  'richards',
#  'don',
#  'give',
#  'sh',
#  'what',
#  'kyle',
#  'thinks',
#  'about',
#  'me',
#  'she',
#  'can',
#  'ck',
#  'off',
#  'can',
#  'tell',
#  'you',
#  'when',
#  'she',
#  'will',
#  'die',
#  'and',
#  'what',
#  'will',
#  'happen',
#  'to',
#  'her',
#  'family',
#  'love',
#  'that',
#  'about',
#  'me',
#  'kyle',
#  'is',
#  'little',
#  'bitch',
#  'kyle',
#  'was',
#  'every',
#  'girl',
#  'at',
#  'high',
#  'school',
#  'that',
#  'made',
#  'somebody',
#  'kill',
#  'themselves',
#  'she',
#  'that',
#  'girl',
#  'that',
#  'so',
#  'mean',
#  'and',
#  'profoundly',
#  'bankrupt',
#  'going',
#  'to',
#  'shove',
#  'this',
#  'electronic',
#  'cigarette',
#  'up',
#  'her',
#  'ass',
#  'to',
#  'make',
#  'point',
#  'except',
#  'she',
#  'need',
#  'bigger',
#  'one',
#  'to',
#  'even',
#  'feel',
#  'it',
#  'oh',
#  'yeah',
#  'went',
#  'there',
#  'and',
#  'can',
#  'say',
#  'this',
#  'if',
#  'any',
#  'of',
#  'their',
#  'children',
#  'disappeared',
#  'they',
#  'wouldn',
#  'be',
#  'like',
#  'you',
#  'were',
#  'wrong',
#  'they',
#  'be',
#  'like',
#  'can',
#  'you',
#  'help',
#  'ck',
#  'them',
#  'relatively',
#  'new',
#  'here',
#  'and',
#  'am',
#  'uncertain',
#  'of',
#  'the',
#  'guidelines',
#  'for',
#  'editing',
#  'protected',
#  'entries',
#  'pulled',
#  'these',
#  'quotes',
#  'directly',
#  'from',
#  'the',
#  'show',
#  'and',
#  'in',
#  'some',
#  'cases',
#  'replayed',
#  'segments',
#  'to',
#  'verify',
#  'their',
#  'accuracy',
#  'pretty',
#  'certain',
#  'that',
#  'they',
#  'are',
#  'accurate',
#  'quotes',
#  'although',
#  'some',
#  'minor',
#  'words',
#  'may',
#  'differ',
#  'given',
#  'that',
#  'dubois',
#  'said',
#  'these',
#  'things',
#  'on',
#  'reality',
#  'television',
#  'show',
#  'think',
#  'that',
#  'it',
#  'notable',
#  'and',
#  'should',
#  'be',
#  'included',
#  'in',
#  'her',
#  'biography',
#  'run',
#  'the',
#  'blog',
#  'celebitchy',
#  'and',
#  'have',
#  'also',
#  'posted',
#  'the',
#  'quotes',
#  'there',
#  'you',
#  'are',
#  'welcome',
#  'to',
#  'delete',
#  'this',
#  'link',
#  'if',
#  'it',
#  'violates',
#  'guidelines',
#  'this',
#  'is',
#  'just',
#  'to',
#  'provide',
#  'reference']

# %%
import csv
# Subsample from test data set to get human dataset
subsample = test_data[0:1000]
subsample_labels= test_labels[0:1000]
# save to disk
with open('../Terminator Mode/subsampled.csv', "w") as outfile:
        for entries in subsample:
            print(subsample)
            outfile.write(entries)
            outfile.write("\n")
with open('../Terminator Mode/subsampled_labels.csv', "w") as outfile:
        for entries in subsample_labels:
            outfile.write(entries)
            outfile.write("\n")
# Out:
# [['appearance', 'on', 'real', 'housewives', 'of', 'beverly', 'hills', 'allison', 'dubois', 'was', 'dinner', 'guest', 'of', 'cast', 'member', 'camille', 'grammer', 'on', 'the', 'episode', 'of', 'the', 'real', 'housewives', 'of', 'beverly', 'hills', 'that', 'aired', 'december', 'entries', 'to', 'her', 'biography', 'that', 'refer', 'to', 'her', 'guest', 'appearance', 'have', 'been', 'deleted', 'and', 'deemed', 'vandalism', 'her', 'appearance', 'was', 'notable', 'and', 'should', 'be', 'included', 'in', 'her', 'biography', 'maybe', 'more', 'neutrally', 'worded', 'entry', 'can', 'be', 'added', 'that', 'includes', 'her', 'behavior', 'and', 'some', 'of', 'the', 'things', 'she', 'said', 'on', 'the', 'show', 'direct', 'quotes', 'from', 'dubois', 'to', 'cast', 'member', 'kyle', 'richards', 'include', 'your', 'husband', 'will', 'never', 'emotionally', 'fulfill', 'you', 'know', 'that', 'as', 'soon', 'as', 'the', 'kids', 'are', 'bigger', 'you', 'll', 'have', 'nothing', 'in', 'common', 'you', 'are', 'entirely', 'washed', 'up', 'and', 'you', 'have', 'achieved', 'nothing', 'in', 'life', 'dubois', 'comments', 'to', 'the', 'entire', 'dinner', 'party', 'guests', 'concerning', 'her', 'abilities', 'and', 'career', 'include', 'was', 'studied', 'by', 'scientist', 'and', 'was', 'on', 'oprah', 'like', 'drug', 'once', 'you', 'get', 'one', 'you', 'want', 'more', 'and', 'have', 'books', 'written', 'on', 'me', 'and', 'by', 'me', 'and', 'television', 'show', 'is', 'based', 'on', 'my', 'life', 'so', 'you', 'can', 'just', 'like', 'take', 'flying', 'leap', 'after', 'the', 'party', 'was', 'over', 'dubois', 'spoke', 'to', 'her', 'friend', 'camille', 'grammer', 'and', 'grammer', 'friend', 'about', 'kyle', 'richards', 'she', 'said', 'of', 'richards', 'don', 'give', 'sh', 'what', 'kyle', 'thinks', 'about', 'me', 'she', 'can', 'ck', 'off', 'can', 'tell', 'you', 'when', 'she', 'will', 'die', 'and', 'what', 'will', 'happen', 'to', 'her', 'family', 'love', 'that', 'about', 'me', 'kyle', 'is', 'little', 'bitch', 'kyle', 'was', 'every', 'girl', 'at', 'high', 'school', 'that', 'made', 'somebody', 'kill', 'themselves', 'she', 'that', 'girl', 'that', 'so', 'mean', 'and', 'profoundly', 'bankrupt', 'going', 'to', 'shove', 'this', 'electronic', 'cigarette', 'up', 'her', 'ass', 'to', 'make', 'point', 'except', 'she', 'need', 'bigger', 'one', 'to', 'even', 'feel', 'it', 'oh', 'yeah', 'went', 'there', 'and', 'can', 'say', 'this', 'if', 'any', 'of', 'their', 'children', 'disappeared', 'they', 'wouldn', 'be', 'like', 'you', 'were', 'wrong', 'they', 'be', 'like', 'can', 'you', 'help', 'ck', 'them', 'relatively', 'new', 'here', 'and', 'am', 'uncertain', 'of', 'the', 'guidelines', 'for', 'editing', 'protected', 'entries', 'pulled', 'these', 'quotes', 'directly', 'from', 'the', 'show', 'and', 'in', 'some', 'cases', 'replayed', 'segments', 'to', 'verify', 'their', 'accuracy', 'pretty', 'certain', 'that', 'they', 'are', 'accurate', 'quotes', 'although', 'some', 'minor', 'words', 'may', 'differ', 'given', 'that', 'dubois', 'said', 'these', 'things', 'on', 'reality', 'television', 'show', 'think', 'that', 'it', 'notable', 'and', 'should', 'be', 'included', 'in', 'her', 'biography', 'run', 'the', 'blog', 'celebitchy', 'and', 'have', 'also', 'posted', 'the', 'quotes', 'there', 'you', 'are', 'welcome', 'to', 'delete', 'this', 'link', 'if', 'it', 'violates', 'guidelines', 'this', 'is', 'just', 'to', 'provide', 'reference'], ['think', 'sandy', 'is', 'capable', 'enough', 'of', 'defending', 'herself', 'on', 'her', 'own', 'and', 'does', 'not', 'need', 'wiki', 'lawyers', 'going', 'aroung', 'sending', 'warnings', 'if', 'she', 'wants', 'to', 'warn', 'wikidea', 'about', 'what', 'she', 'perceives', 'as', 'misconduct', 'or', 'if', 'she', 'wants', 'to', 'point', 'out', 'possible', 'infringements', 'of', 'wiki', 'policies', 'by', 'wikidea', 'or', 'any', 'other', 'user', 'she', 'can', 'do', 'it', 'herself', 'as', 'she', 'has', 'already', 'done', 'it', 'once', 'in', 'the', 'far', 'in', 'question', 'any', 'o ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-a6f13b60c877> in <module>
#       7         for entries in subsample:
#       8             print(subsample)
# ----> 9             outfile.write(entries)
#      10             outfile.write("\n")
#      11 with open('../Terminator Mode/subsampled_labels.csv', "w") as outfile:
#
# TypeError: write() argument must be str, not list

# %%
'''Simple preprocess removes common accent marks and converts the text to lowercase. 
Contrast to more advanced preprocessing techniques in tf-idf.'''
preprocessed_comments = []
for i, line in enumerate(comments):
    preprocessed_comments.append(gensim.utils.simple_preprocess(line))
for i, line in enumerate(comments_test):
    preprocessed_comments.append(gensim.utils.simple_preprocess(line))
preprocessed_comments_total = preprocessed_comments.copy()
for i, line in enumerate(comments_unlabelled_test):
    preprocessed_comments_total.append(gensim.utils.simple_preprocess(line))

# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(train_data)]
# %time model = Doc2Vec(documents, min_count=1, workers=4)
# Out:
# Wall time: 1min 25s

# %%
print(len(train_data[0]))
model[documents[0]].shape
# Out:
# 47
# (48, 100)

# %%
def translate_to_doc2vec(comments):
    for i, comment in enumerate(comments):
